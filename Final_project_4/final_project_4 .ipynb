# %% [markdown]
# Load File

# %%
import pandas as pd 

df = pd.read_csv(r"C:\Users\SYAMNARAYANAN\OneDrive\Desktop\visual code\Guvi_Project_3\JEE_Dropout_After_Class_12.csv")

# %%
df
# Out:
#       jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 0              78.95               59.22                59.86         CBSE
# 1              70.06               58.75                64.33        State
# 2              81.07               37.27                60.83         ICSE
# 3              93.32               60.72                69.33         ICSE
# 4              68.72               77.73                82.37         CBSE
# ...              ...                 ...                  ...          ...
# 4995           71.31               86.82                57.08        State
# 4996           81.96               34.03                82.85         CBSE
# 4997          100.00               54.71                83.75         CBSE
# 4998           83.31               73.93                57.39         CBSE
# 4999           60.13               76.31                66.15        State
#
# ...

# %%
df.isnull().sum()
# Out:
# jee_main_score             0
# jee_advanced_score         0
# mock_test_score_avg        0
# school_board               0
# class_12_percent           0
# attempt_count              0
# coaching_institute      1209
# daily_study_hours          0
# family_income              0
# parent_education           0
# location_type              0
# peer_pressure_level        0
# mental_health_issues       0
# admission_taken            0
# dropout                    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   jee_main_score        5000 non-null   float64
#  1   jee_advanced_score    5000 non-null   float64
#  2   mock_test_score_avg   5000 non-null   float64
#  3   school_board          5000 non-null   object
#  4   class_12_percent      5000 non-null   float64
#  5   attempt_count         5000 non-null   int64
#  6   coaching_institute    3791 non-null   object
#  7   daily_study_hours     5000 non-null   float64
#  8   family_income         5000 non-null   object
#  9   parent_education      5000 non-null   object
#  10  location_type         5000 non-null   object
#  11  peer_pressure_level   5000 non-null   object
#  12  mental_health_issues  5000 non-null   object
#  13  admission_taken       5000 non-null   object
#  14  dropout               5000 non-null   int64
# ...

# %% [markdown]
# Statistical Analysis

# %%
df.describe()
# Out:
#        jee_main_score  jee_advanced_score  mock_test_score_avg  \
# count     5000.000000         5000.000000          5000.000000
# mean        71.961226           65.736404            68.110756
# std         13.668497           15.909248            11.938849
# min         26.620000            3.240000            27.490000
# 25%         62.790000           55.017500            60.070000
# 50%         72.190000           65.720000            68.120000
# 75%         81.322500           76.835000            76.110000
# max        100.000000          100.000000           100.000000
#
#        class_12_percent  attempt_count  daily_study_hours      dropout
# count       5000.000000    5000.000000        5000.000000  5000.000000
# mean          74.957400       1.504600           4.483860     0.207200
# std            9.885309       0.500029           1.984723     0.405341
# min           50.000000       1.000000           0.000000     0.000000
# ...

# %%
df['coaching_institute'] = df['coaching_institute'].fillna("Unknown")

# %% [markdown]
#  Analysis

# %%
df.groupby('school_board')['dropout'].value_counts()
# Out:
# school_board  dropout
# CBSE          0          1374
#               1           364
# ICSE          0          1322
#               1           338
# State         0          1268
#               1           334
# Name: count, dtype: int64

# %%
df.groupby('coaching_institute')['dropout'].value_counts()
# Out:
# coaching_institute  dropout
# Allen               0           987
#                     1           241
# FIITJEE             0          1003
#                     1           295
# Local               0          1011
#                     1           254
# Unknown             0           963
#                     1           246
# Name: count, dtype: int64

# %%
df.groupby('parent_education')['dropout'].value_counts()
# Out:
# parent_education  dropout
# 12th              0           978
#                   1           265
# Graduate          0           985
#                   1           239
# PG                0           973
#                   1           272
# Upto 10th         0          1028
#                   1           260
# Name: count, dtype: int64

# %%
df.groupby('family_income')['dropout'].value_counts()
# Out:
# family_income  dropout
# High           0          1588
#                1            75
# Low            1           892
#                0           787
# Mid            0          1589
#                1            69
# Name: count, dtype: int64

# %%
analaysis = df.query('daily_study_hours >7 & family_income == "Low" &  school_board == "ICSE"')
analaysis
# Out:
#       jee_main_score  jee_advanced_score  mock_test_score_avg school_board  \
# 13             45.21               62.20                62.41         ICSE
# 194            74.42               36.45                63.98         ICSE
# 198            72.81               52.46                83.50         ICSE
# 230            61.77               94.92                79.46         ICSE
# 346            51.73               61.60                78.65         ICSE
# ...              ...                 ...                  ...          ...
# 4664           82.06               56.53                77.93         ICSE
# 4670           81.13               68.99                73.02         ICSE
# 4704           80.08               74.68                49.78         ICSE
# 4922           80.22               38.50                67.55         ICSE
# 4954           76.58               70.07                74.04         ICSE
#
# ...

# %% [markdown]
# Data Preprocessing

# %%
df.select_dtypes(include=object)
# Out:
#      school_board coaching_institute family_income parent_education  \
# 0            CBSE            FIITJEE           Low        Upto 10th
# 1           State            FIITJEE           Mid        Upto 10th
# 2            ICSE            FIITJEE           Low               PG
# 3            ICSE            FIITJEE           Low             12th
# 4            CBSE              Allen           Mid         Graduate
# ...           ...                ...           ...              ...
# 4995        State            FIITJEE          High               PG
# 4996         CBSE              Local           Mid               PG
# 4997         CBSE            Unknown           Mid               PG
# 4998         CBSE              Allen          High        Upto 10th
# 4999        State            FIITJEE           Mid             12th
#
#      location_type peer_pressure_level mental_health_issues admission_taken
# ...

# %%
df = pd.get_dummies(df,columns=['school_board','coaching_institute'],drop_first=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   jee_main_score              5000 non-null   float64
#  1   jee_advanced_score          5000 non-null   float64
#  2   mock_test_score_avg         5000 non-null   float64
#  3   class_12_percent            5000 non-null   float64
#  4   attempt_count               5000 non-null   int64
#  5   daily_study_hours           5000 non-null   float64
#  6   family_income               5000 non-null   object
#  7   parent_education            5000 non-null   object
#  8   location_type               5000 non-null   object
#  9   peer_pressure_level         5000 non-null   object
#  10  mental_health_issues        5000 non-null   object
#  11  admission_taken             5000 non-null   object
#  12  dropout                     5000 non-null   int64
# ...

# %%
df[['school_board_ICSE', 'school_board_State','coaching_institute_FIITJEE', 'coaching_institute_Local','coaching_institute_Unknown']] =df[['school_board_ICSE', 'school_board_State','coaching_institute_FIITJEE', 'coaching_institute_Local','coaching_institute_Unknown']].astype(int)

# %%
df
# Out:
#       jee_main_score  jee_advanced_score  mock_test_score_avg  \
# 0              78.95               59.22                59.86
# 1              70.06               58.75                64.33
# 2              81.07               37.27                60.83
# 3              93.32               60.72                69.33
# 4              68.72               77.73                82.37
# ...              ...                 ...                  ...
# 4995           71.31               86.82                57.08
# 4996           81.96               34.03                82.85
# 4997          100.00               54.71                83.75
# 4998           83.31               73.93                57.39
# 4999           60.13               76.31                66.15
#
#       class_12_percent  attempt_count  daily_study_hours family_income  \
# 0                70.09              1                5.4           Low
# 1                78.00              1                5.5           Mid
# ...

# %%
df['family_income'] = df['family_income'].map({'Low':0, 'Mid':1, 'High':2})

# %%
df['parent_education'].value_counts()
# Out:
# parent_education
# Upto 10th    1288
# PG           1245
# 12th         1243
# Graduate     1224
# Name: count, dtype: int64

# %%
df['parent_education'] = df['parent_education'].map({'Upto 10th':1, 'PG':4, '12th':2, 'Graduate':3})

# %%
df = pd.get_dummies(df,columns=['location_type'])

# %%
df.columns
# Out:
# Index(['jee_main_score', 'jee_advanced_score', 'mock_test_score_avg',
#        'class_12_percent', 'attempt_count', 'daily_study_hours',
#        'family_income', 'parent_education', 'peer_pressure_level',
#        'mental_health_issues', 'admission_taken', 'dropout',
#        'school_board_ICSE', 'school_board_State', 'coaching_institute_FIITJEE',
#        'coaching_institute_Local', 'coaching_institute_Unknown',
#        'location_type_Rural', 'location_type_Semi-Urban',
#        'location_type_Urban'],
#       dtype='object')

# %%
df[['location_type_Rural', 'location_type_Semi-Urban','location_type_Urban']] = df[['location_type_Rural', 'location_type_Semi-Urban','location_type_Urban']].astype(int)

# %%
df.select_dtypes(include=[object]).head(5)
# Out:
#   peer_pressure_level mental_health_issues admission_taken
# 0                 Low                   No              No
# 1                 Low                  Yes              No
# 2              Medium                  Yes              No
# 3              Medium                  Yes             Yes
# 4                High                   No             Yes

# %%
df['peer_pressure_level'].unique()
# Out:
# array(['Low', 'Medium', 'High'], dtype=object)

# %%
df['peer_pressure_level']= df['peer_pressure_level'].map({'Low':0, 'Medium':1, 'High':2})

# %%
from sklearn.preprocessing import LabelEncoder

scaler = LabelEncoder()

df['mental_health_issues'] = scaler.fit_transform(df['mental_health_issues'])


df['admission_taken'] = scaler.fit_transform(df['admission_taken'])

# %%
df.columns
# Out:
# Index(['jee_main_score', 'jee_advanced_score', 'mock_test_score_avg',
#        'class_12_percent', 'attempt_count', 'daily_study_hours',
#        'family_income', 'parent_education', 'peer_pressure_level',
#        'mental_health_issues', 'admission_taken', 'dropout',
#        'school_board_ICSE', 'school_board_State', 'coaching_institute_FIITJEE',
#        'coaching_institute_Local', 'coaching_institute_Unknown',
#        'location_type_Rural', 'location_type_Semi-Urban',
#        'location_type_Urban'],
#       dtype='object')

# %%
correaltion = df.corr()
correaltion['dropout'].sort_values(ascending=False)
# Out:
# dropout                       1.000000
# peer_pressure_level           0.081947
# coaching_institute_FIITJEE    0.029326
# location_type_Urban           0.028239
# mock_test_score_avg           0.014728
# mental_health_issues          0.012177
# class_12_percent              0.009778
# parent_education              0.008928
# school_board_State            0.002184
# location_type_Semi-Urban     -0.004063
# coaching_institute_Unknown   -0.005192
# school_board_ICSE            -0.006237
# coaching_institute_Local     -0.009203
# attempt_count                -0.012599
# jee_advanced_score           -0.015334
# location_type_Rural          -0.024089
# jee_main_score               -0.027040
# daily_study_hours            -0.126112
# admission_taken              -0.410321
# family_income                -0.491128
# Name: dropout, dtype: float64

# %%
from sklearn.ensemble import RandomForestClassifier

x = df.drop('dropout',axis=1)
y = df['dropout']

test_model = RandomForestClassifier()
test_model.fit(x,y)

importance = test_model.feature_importances_
feature = x.columns

importnce_df = pd.DataFrame({
    "feature_name":feature,
    "importances":importance
    }).sort_values(by = 'importances',ascending = False)


importnce_df.head(10).plot.bar(x  = 'feature_name', y ='importances')
# Out:
# <Axes: xlabel='feature_name'>

# %%
importnce_df['feature_name'].head(10).to_list()
# Out:
# ['family_income',
#  'admission_taken',
#  'daily_study_hours',
#  'peer_pressure_level',
#  'jee_main_score',
#  'jee_advanced_score',
#  'mock_test_score_avg',
#  'class_12_percent',
#  'parent_education',
#  'mental_health_issues']

# %%
df.columns
# Out:
# Index(['jee_main_score', 'jee_advanced_score', 'mock_test_score_avg',
#        'class_12_percent', 'attempt_count', 'daily_study_hours',
#        'family_income', 'parent_education', 'peer_pressure_level',
#        'mental_health_issues', 'admission_taken', 'dropout',
#        'school_board_ICSE', 'school_board_State', 'coaching_institute_FIITJEE',
#        'coaching_institute_Local', 'coaching_institute_Unknown',
#        'location_type_Rural', 'location_type_Semi-Urban',
#        'location_type_Urban'],
#       dtype='object')

# %%
import seaborn as sns   
select_feature = ['family_income',
 'admission_taken',
 'daily_study_hours',
 'peer_pressure_level',
 'jee_main_score',
 'jee_advanced_score',
 'class_12_percent',
 'mock_test_score_avg',
 'parent_education',
 'mental_health_issues','dropout']

sns.pairplot(data=df[select_feature], hue='dropout')

# %% [markdown]
# Class Imbalance Check

# %%
df['dropout'].value_counts()
# Out:
# dropout
# 0    3964
# 1    1036
# Name: count, dtype: int64

# %% [markdown]
# Train-Test Split

# %%
from sklearn.model_selection import train_test_split,cross_val_score

X = df[['family_income',
 'admission_taken',
 'daily_study_hours',
 'peer_pressure_level',
 'jee_main_score',
 'jee_advanced_score',
 'mock_test_score_avg',
 'class_12_percent',
 'parent_education',
 'mental_health_issues']]
y = df['dropout']


X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=20)

# %%
X_train.shape
# Out:
# (4000, 10)

# %%
X_test.shape
# Out:
# (1000, 10)

# %%
y_test.shape
# Out:
# (1000,)

# %%
y_test.value_counts()
# Out:
# dropout
# 0    800
# 1    200
# Name: count, dtype: int64

# %%
y_train.value_counts()
# Out:
# dropout
# 0    3164
# 1     836
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE()

X_resample,y_resample = smote.fit_resample(X_train,y_train)
# Out:
# c:\Users\SYAMNARAYANAN\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(

# %%
y_resample.value_counts()
# Out:
# dropout
# 0    3164
# 1    3164
# Name: count, dtype: int64

# %%
sns.countplot(data=df,x = y_resample)
# Out:
# <Axes: xlabel='dropout', ylabel='count'>

# %% [markdown]
# Model Comparison

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score,f1_score,recall_score,precision_score

models = {
    "LogisticRegression":LogisticRegression(),
    "DecisionTreeClassifier":DecisionTreeClassifier(),
    "RandomForestClassifier":RandomForestClassifier(),
    "DecisionTreeClassifier":DecisionTreeClassifier(),
    "KNeighborsClassifier":KNeighborsClassifier(),


}

for name , model in models.items():
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    r2 = accuracy_score(y_test,y_pred)
    cross  = cross_val_score(model,X_train,y_train ,scoring = 'accuracy' , cv=5)
    print(f"{name} r2 score: {r2:.3f}")
    print(cross)
    print("---"*5)
# Out:
# c:\Users\SYAMNARAYANAN\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\SYAMNARAYANAN\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %% [markdown]
# Model Evaluation – Classification

# %%
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,f1_score

model = RandomForestClassifier()

model.fit(X_resample,y_resample)

y_predt = model.predict(X_test)

score = classification_report(y_test,y_predt)

print(score)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       800
#            1       0.99      0.99      0.99       200
#
#     accuracy                           0.99      1000
#    macro avg       0.99      0.99      0.99      1000
# weighted avg       1.00      0.99      1.00      1000

# %%
martix  =confusion_matrix(y_test,y_predt)
martix
# Out:
# array([[797,   3],
#        [  2, 198]])

# %%
croos_score = cross_val_score(model,X_resample,y_resample,cv=5)
croos_score
# Out:
# array([0.98657188, 0.99526066, 0.99210111, 0.9944664 , 0.98814229])

# %%
pd.crosstab(y_test,y_predt)
# Out:
# col_0      0    1
# dropout
# 0        797    3
# 1          2  198

# %%
f1_score(y_test,y_predt)
# Out:
# 0.9875311720698254

# %% [markdown]
# Deployment

# %%
import joblib

joblib.dump(model,"final_project_4 drop_out.pkl")
# Out:
# ['final_project_4 drop_out.pkl']

# %%
joblib.load('final_project_4 drop_out.pkl')
# Out:
# RandomForestClassifier()
